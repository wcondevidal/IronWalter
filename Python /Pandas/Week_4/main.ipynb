# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here

import numpy as np 
import pandas as pd

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `temp_states`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here

temp = pd.read_csv("data/Temp_States.csv")

# %% [markdown]
# #### Print `temp`.

# %%
# your code here

temp.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here

temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

temp[(temp["State"]=="New York")]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here

temp[(temp["State"]=="New York")].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here

temp[(temp["Temperature"]>15)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here

filtered = temp[(temp["Temperature"]>15)]

filtered[["City","Temperature"]]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here

filtered2 = temp[(temp["Temperature"]>15)&(temp["Temperature"]<20)]

filtered2[["City","Temperature"]]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here

mean = temp.groupby("State").mean("Temperature")

std = temp.groupby("State").std()

mean.merge(std, on="State", how="left")
# Out:
#              Temperature_x  Temperature_y
# State
# Connecticut      15.833333       1.964186
# New Jersey       21.111111       1.571348
# New York         10.740741       8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here

emp = pd.read_csv("data/employee.csv")

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here

emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %%
emp.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here


emp["Salary"].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here

emp["Salary"].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here

emp["Salary"].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here

filtered1 = emp[(emp["Salary"]<emp["Salary"].mean())]

filtered1
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30
# 3  Sonia         HR  Bachelor      F  analyst      4      35

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here

filtered2 = emp[(emp["Name"] == "David")]

filtered2
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here

filtered2 = emp[(emp["Name"] == "David")]

filtered2[["Name","Salary"]]
# Out:
#     Name  Salary
# 2  David      30

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here

filtered3 = emp[(emp["Title"] == "associate")]

filtered3
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here

emp.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here

emp.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here

filtered4 = emp[(emp["Title"] == "associate")&(emp["Salary"]>55)]

filtered4
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here

emp_ny = emp.groupby(["Years"])

emp_ny["Salary"].agg([np.mean])
# Out:
#             mean
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here

emp_t = emp.groupby(["Title"])

emp_t["Salary"].agg([np.mean])
# Out:
#                 mean
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

emp["Salary"].quantile([0.25, 0.75])
# Out:
# 0.25    35.0
# 0.75    60.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here

emp_gn = emp.groupby(["Gender"])

emp_gn["Salary"].agg([np.mean])
# Out:
#         mean
# Gender
# F       47.5
# M       50.0

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here

emp_dp = emp.groupby(["Department"])

emp_dp[["Salary","Years"]].agg([np.mean,np.min,np.max])
# Out:
#            Salary               Years
#              mean amin amax      mean amin amax
# Department
# HR          45.00   30   70  4.666667    2    8
# IT          48.75   30   70  4.500000    1    8
# Sales       55.00   55   55  2.500000    2    3

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # Challenge 3
# #### Open the `orders` dataset. Name your dataset `orders`.

# %%
# your code here

ords = pd.read_csv("data/orders.csv")

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here

ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
"""
your comments here
"""
ords.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here

ords["UnitPrice"].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here

print("Min:",ords["UnitPrice"].min(), "Max:", ords["UnitPrice"].max())
# Out:
# Min: 0.0 Max: 8142.75

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here

filtered1 = ords[(ords["Country"] == "Spain")]

filtered1
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here

filtered1[["Country"]].count()
# Out:
# Country    2485
# dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
ords_q = ords.groupby(["CustomerID"])

ords_q.first()
# Out:
#             Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# CustomerID
# 12346            61619     541431     23166  2011      1    2    10
# 12347            14938     537626     85116  2010     12    2    14
# 12348            34083     539318     84992  2010     12    4    19
# 12349           485502     577609     23112  2011     11    1     9
# 12350            80323     543037     21908  2011      2    3    16
# ...                ...        ...       ...   ...    ...  ...   ...
# 18280           111045     545712     82484  2011      3    1     9
# 18281           222954     556464     22037  2011      6    7    10
# 18282           291854     562525     21270  2011      8    5    13
# 18283            46026     540350     22356  2011      1    4    14
# 18287           198716     554065     22755  2011      5    7    10
#
#                                   Description  Quantity          InvoiceDate  \
# CustomerID
# ...

# %%
pd.Series(ords[ords["Quantity"] > 50].CustomerID.unique())
# Out:
# 0       13748
# 1       15291
# 2       14688
# 3       16029
# 4       17511
#         ...
# 1296    14032
# 1297    15520
# 1298    15877
# 1299    13298
# 1300    16446
# Length: 1301, dtype: int64

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here

filtered2 = ords[(ords["Country"] == "Spain") & (ords["Quantity"] > 50)]

filtered2
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here

filtered3 = ords[(ords["amount_spent"] == 0)]

filtered3
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here

filtered4 = ords[(ords["Description"].str.contains("lunch bag"))]

filtered4
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here

filtered5 = ords[(ords["Description"].str.contains("lunch bag"))&(ords["year"] == 2011)]

filtered5
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here

ords["Country"].value_counts().filter(["Spain"])
# Out:
# Spain    2485
# Name: Country, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here

filtered6 = ords[(ords["month"] == 8)]

filtered6
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here

filtered7 = ords[(ords["month"] == 8)]

filtered7[["Country"]].value_counts()
# Out:
# Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
peter = ords.groupby(["Country"])

peter["amount_spent"].agg([np.mean])
# Out:
#                             mean
# Country
# Australia             116.895620
# Austria                25.624824
# Bahrain                32.258824
# Belgium                20.283772
# Brazil                 35.737500
# Canada                 24.280662
# Channel Islands        27.340160
# Cyprus                 22.134169
# Czech Republic         33.069600
# Denmark                49.882474
# EIRE                   36.687745
# European Community     21.670833
# Finland                32.913985
# France                 25.056827
# Germany                25.311562
# Greece                 32.831172
# Iceland                23.681319
# Israel                 29.119718
# Italy                  23.064960
# Japan                 116.561900
# Lebanon                37.641778
# Lithuania              47.458857
# Malta                  24.335625
# Netherlands           120.798282
# Norway                 33.736418
# Poland                 22.226212
# Portugal               22.872702
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here

ords["UnitPrice"].max()
# Out:
# 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here

peter2 = ords.groupby(["year"])

peter2["amount_spent"].agg([np.mean])
# Out:
#            mean
# year
# 2010  21.892733
# 2011  22.430074
